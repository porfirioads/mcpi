# %% [markdown]
# # Consumo de alcohol en estudiantes
#
# ## Descripción
#
# Este notebook analiza un conjunto de estudiantes de matemáticas de escuela secundaria, contiene información acerca de intereses sociales, género y estudios, así como su consumo de alcohol. El dataset además podría ser utilizado para predecir la calificación final de los estudiantes.
#
# ## Link del dataset
#
# https://www.kaggle.com/uciml/student-alcohol-consumption
#
# ## Columnas del dataset
#
#
# **school** - student's school (binary: 'GP' - Gabriel Pereira or 'MS' - Mousinho da Silveira)
#
# **sex** - student's sex (binary: 'F' - female or 'M' - male)
#
# **age** - student's age (numeric: from 15 to 22)
#
# **address** - student's home address type (binary: 'U' - urban or 'R' - rural)
#
# **famsize** - family size (binary: 'LE3' - less or equal to 3 or 'GT3' - greater than 3)
#
# **Pstatus** - parent's cohabitation status (binary: 'T' - living together or 'A' - apart)
#
# **Medu** - mother's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# **Fedu** - father's education (numeric: 0 - none, 1 - primary education (4th grade), 2 – 5th to 9th grade, 3 – secondary education or 4 – higher education)
#
# **Mjob** - mother's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
# **Fjob** - father's job (nominal: 'teacher', 'health' care related, civil 'services' (e.g. administrative or police), 'at_home' or 'other')
#
# **reason** - reason to choose this school (nominal: close to 'home', school 'reputation', 'course' preference or 'other')
#
# **guardian** - student's guardian (nominal: 'mother', 'father' or 'other')
#
# **traveltime** - home to school travel time (numeric: 1 - 1 hour)
#
# **studytime** - weekly study time (numeric: 1 - 10 hours)
#
# **failures** - number of past class failures (numeric: n if 1<=n<3, else 4)
#
# **schoolsup** - extra educational support (binary: yes or no)
#
# **famsup** - family educational support (binary: yes or no)
#
# **paid** - extra paid classes within the course subject (Math or Portuguese) (binary: yes or no)
#
# **activities** - extra-curricular activities (binary: yes or no)
#
# **nursery** - attended nursery school (binary: yes or no)
#
# **higher** - wants to take higher education (binary: yes or no)
#
# **internet** - Internet access at home (binary: yes or no)
#
# **romantic** - with a romantic relationship (binary: yes or no)
#
# **famrel** - quality of family relationships (numeric: from 1 - very bad to 5 - excellent)
#
# **freetime** - free time after school (numeric: from 1 - very low to 5 - very high)
#
# **goout** - going out with friends (numeric: from 1 - very low to 5 - very high)
#
# **Dalc** - workday alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# **Walc** - weekend alcohol consumption (numeric: from 1 - very low to 5 - very high)
#
# **health** - current health status (numeric: from 1 - very bad to 5 - very good)
#
# **absences** - number of school absences (numeric: from 0 to 93)
#
# These grades are related with the course subject, Math or Portuguese:
#
# **G1** - first period grade (numeric: from 0 to 20)
#
# **G2** - second period grade (numeric: from 0 to 20)
#
# **G3** - final grade (numeric: from 0 to 20, output target)

# %% [markdown]
# ## Previsualización

# %%
# Importación de librerías
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Lee el dataset.
data = pd.read_csv('datasets/student_mat.csv')
data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
# Medidas de tendencia central.
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
# Crea boxplots de las características.
data.boxplot(grid='True', figsize=(15, 6))
plt.title('Boxplot de la edad de los estudiantes')
plt.show()

# %%
data = pd.read_csv('datasets/student_mat.csv')

# Crea heatmap de correlaciones.
correlation_matrix = data.corr()
plt.figure(figsize = (16,10))
sns.heatmap(correlation_matrix, annot=True, cmap="Blues")
plt.show()

# %%
data = pd.read_csv('datasets/student_mat.csv')

# Crea scatterplot con todas las características.
sns.pairplot(data, kind='scatter')
plt.show()

# %% [markdown]
# ## Conversión de datos categóricos a numéricos

# %%
# Lee el dataset.
data = pd.read_csv('datasets/student_mat.csv')

# Define cuáles características son strings y cuáles numéricas.
str_cols = ['school', 'sex', 'address', 'famsize', 'Pstatus', 'Mjob', 'Fjob', 
               'reason', 'guardian', 'schoolsup', 'famsup', 'paid', 'activities', 
               'nursery', 'higher', 'internet', 'romantic']
num_cols = [col for col in data.columns if col not in str_cols]
print(f'Hay {len(str_cols)} columnas con valor string')
print(f'Hay {len(num_cols)} columnas con valor numérico')

# Recorre cada columna string para transformarla a número.
for col in str_cols:
    # Obtiene valores únicos en la característica.
    unique_values = data[col].unique()
    # Crea una categoría por cada valor único, usamos ordered en False
    # porque las características no tienen un orden.
    data[col] = pd.Categorical(data[col], unique_values, ordered=False)
    # Reemplaza el valor de la columna por su código.
    data[col] = data[col].cat.codes
print('Las categorías fueron convertidas a números')
# Out:
# Hay 17 columnas con valor string
# Hay 16 columnas con valor numérico
# Las categorías fueron convertidas a números

# %%
# Calcula promedio entre calificaciones parciales y elimina éstas.
data['PROMEDIO'] = (data['G1'] + data['G2'] + data['G3']) / 3
data['PROMEDIO'] = data['PROMEDIO'].round(1)
data = data.drop(columns=['G1', 'G2', 'G3'])
data
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        0        0        0     4     4     0     0  ...
# 1         0    0   17        0        0        1     1     1     0     1  ...
# 2         0    0   15        0        1        1     1     1     0     1  ...
# 3         0    0   15        0        0        1     4     2     1     2  ...
# 4         0    0   16        0        0        1     3     3     2     1  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        0        1        0     2     2     3     2  ...
# 391       1    1   17        0        1        1     3     1     3     2  ...
# 392       1    1   21        1        0        1     1     1     2     1  ...
# 393       1    1   18        1        1        1     3     2     3     1  ...
# 394       1    1   19        0        1        1     1     1     2     4  ...
#
# ...

# %%
# Crea heatmap de correlaciones.
correlation_matrix = data.corr()
plt.figure(figsize = (16,10))
sns.heatmap(correlation_matrix, annot=False, cmap="Blues")
plt.show()

# %%
# Crea scatterplot con todas las características.
sns.pairplot(data, kind='scatter')
plt.show()

# %% [markdown]
# # Selección de características

# %%
for col in data.columns:
    print(f'{col}: {data[col].unique()}')
# Out:
# school: [0 1]
# sex: [0 1]
# age: [18 17 15 16 19 22 20 21]
# address: [0 1]
# famsize: [0 1]
# Pstatus: [0 1]
# Medu: [4 1 3 2 0]
# Fedu: [4 1 2 3 0]
# Mjob: [0 1 2 3 4]
# Fjob: [0 1 2 3 4]
# reason: [0 1 2 3]
# guardian: [0 1 2]
# traveltime: [2 1 3 4]
# studytime: [2 3 1 4]
# failures: [0 3 2 1]
# schoolsup: [0 1]
# famsup: [0 1]
# paid: [0 1]
# activities: [0 1]
# nursery: [0 1]
# higher: [0 1]
# internet: [0 1]
# romantic: [0 1]
# famrel: [4 5 3 1 2]
# freetime: [3 2 4 1 5]
# goout: [4 3 2 1 5]
# Dalc: [1 2 5 3 4]
# Walc: [1 3 2 4 5]
# health: [3 5 1 2 4]
# absences: [ 6  4 10  2  0 16 14  7  8 25 12 54 18 26 20 56 24 28  5 13 15 22  3 21
#   1 75 30 19  9 11 38 40 23 17]
# PROMEDIO: [ 5.66666667  5.33333333  8.33333333 14.66666667  8.66666667 15.
#  11.66666667 17.66666667  9.         11.33333333 14.         10.33333333
#  15.33333333 13.66666667  9.33333333 12.66666667  7.66666667 11.
#  10.66666667 16.66666667 16.33333333 10.          7.         13.33333333
# ...

# %%
from libs.feature_selector import FeatureSelector

# Inicializa feature selector especificando el promedio como variable objetivo.
fs = FeatureSelector(data=data, labels=data['Dalc'])
fs.identify_missing(missing_threshold=0.6)
fs.identify_single_unique()
fs.identify_collinear(correlation_threshold=0.3)
fs.plot_collinear()
fs.plot_collinear(plot_all=True)
# Out:
# 0 features with greater than 0.60 missing values.
#
# 0 features with a single unique value.
#
# 8 features with a correlation magnitude greater than 0.30.

# %% [markdown]
# ### Wrapper methods

# %%
X = data.drop("Dalc", 1)       # feature matrix 
y = data['Dalc']               # target feature
print(X)
print(y)
# Out:
#      school  sex  age  address  famsize  Pstatus  Medu  Fedu  Mjob  Fjob  ...  \
# 0         0    0   18        0        0        0     4     4     0     0  ...
# 1         0    0   17        0        0        1     1     1     0     1  ...
# 2         0    0   15        0        1        1     1     1     0     1  ...
# 3         0    0   15        0        0        1     4     2     1     2  ...
# 4         0    0   16        0        0        1     3     3     2     1  ...
# ..      ...  ...  ...      ...      ...      ...   ...   ...   ...   ...  ...
# 390       1    1   20        0        1        0     2     2     3     2  ...
# 391       1    1   17        0        1        1     3     1     3     2  ...
# 392       1    1   21        1        0        1     1     1     2     1  ...
# 393       1    1   18        1        1        1     3     2     3     1  ...
# 394       1    1   19        0        1        1     1     1     2     4  ...
#
# ...

# %%
#importing the necessary libraries
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.linear_model import LinearRegression
# Sequential Forward Selection(sfs)
sfs = SFS(LinearRegression(),
           k_features=5,
           forward=True,
           floating=False,
           scoring = 'r2',
           cv = 0)
sfs.fit(X, y)
sfs.k_feature_names_
# Out:
# ('school', 'sex', 'Mjob', 'freetime', 'Walc')

# %%
#Sequential backward selection(sbs)
sbs = SFS(LinearRegression(), 
          k_features=5, 
          forward=False, 
          floating=False,
          cv=0)
sbs.fit(X, y)
sbs.k_feature_names_
# Out:
# ('sex', 'age', 'schoolsup', 'freetime', 'Walc')

# %%
# Hace selección de 3 a 11 características para comparar resultados.
sfs1 = SFS(LinearRegression(), 
          k_features=(3,30), 
          forward=True, 
          floating=False,
          cv=0)
sfs1.fit(X, y)
# Out:
# SequentialFeatureSelector(clone_estimator=True, cv=0,
#                           estimator=LinearRegression(copy_X=True,
#                                                      fit_intercept=True,
#                                                      n_jobs=None,
#                                                      normalize=False),
#                           fixed_features=None, floating=False, forward=True,
#                           k_features=(3, 30), n_jobs=1, pre_dispatch='2*n_jobs',
#                           scoring=None, verbose=0)

# %%
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
import matplotlib.pyplot as plt
fig1 = plot_sfs(sfs1.get_metric_dict(), kind='std_dev')
plt.title('Sequential Forward Selection (w. StdErr)')
plt.grid()
plt.show()
# Out:
# /home/porfirioadmin/.conda/envs/venv/lib/python3.8/site-packages/numpy/core/_methods.py:216: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/porfirioadmin/.conda/envs/venv/lib/python3.8/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# Sequential Forward Floating Selection (sffs)
sffs = SFS(LinearRegression(), 
          k_features=(3,30), 
          forward=True, 
          floating=True,
          cv=0)
sffs.fit(X, y)
sffs.k_feature_names_
# Out:
# ('school',
#  'sex',
#  'age',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Medu',
#  'Fedu',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'traveltime',
#  'studytime',
#  'failures',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic',
#  'famrel',
#  'freetime',
#  'goout',
#  'Walc',
#  'health',
#  'absences',
#  'PROMEDIO')

# %%
fig1 = plot_sfs(sffs.get_metric_dict(), kind='std_dev')
plt.title('Sequential Forward Selection (w. StdErr)')
plt.grid()
plt.show()
# Out:
# /home/porfirioadmin/.conda/envs/venv/lib/python3.8/site-packages/numpy/core/_methods.py:216: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/porfirioadmin/.conda/envs/venv/lib/python3.8/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# Sequential Forward Floating Selection (sffs)
sffs = SFS(LinearRegression(), 
          k_features=(12), 
          forward=True, 
          floating=True,
          cv=0)
sffs.fit(X, y)
sffs.k_feature_names_
# Out:
# ('school',
#  'sex',
#  'age',
#  'Medu',
#  'Mjob',
#  'Fjob',
#  'guardian',
#  'traveltime',
#  'schoolsup',
#  'activities',
#  'freetime',
#  'Walc')

# %%
fig1 = plot_sfs(sffs.get_metric_dict(), kind='std_dev')
plt.title('Sequential Forward Selection (w. StdErr)')
plt.grid()
plt.show()
# Out:
# /home/porfirioadmin/.conda/envs/venv/lib/python3.8/site-packages/numpy/core/_methods.py:216: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/porfirioadmin/.conda/envs/venv/lib/python3.8/site-packages/numpy/core/_methods.py:209: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# ## Random Forest

# %%
# Importación de librerías.
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score as acc
from mlxtend.feature_selection import SequentialFeatureSelector as sfs

y = data.pop('Dalc')
x = data

# Divide en entrenamiento y prueba.
X_train, X_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.25,
    random_state=42)

y_train = y_train.ravel()
y_test = y_test.ravel()

print('Training dataset shape:', X_train.shape, y_train.shape)
print('Testing dataset shape:', X_test.shape, y_test.shape)
# Out:
# Training dataset shape: (296, 30) (296,)
# Testing dataset shape: (99, 30) (99,)

# %%
# Construye un clasificador random forest para usarlo en la selección
# de características.
clf = RandomForestClassifier(n_estimators=100, n_jobs=-1)

# Construye step forward feature selection
sfs1 = sfs(clf,
           k_features=(2, 15),
           forward=True,
           floating=False,
           verbose=2,
           scoring='accuracy',
           cv=5)

# Ejecuta SFFS
sfs1 = sfs1.fit(X_train, y_train)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   26.2s finished
#
# [2020-06-12 10:50:44] Features: 1/15 -- score: 0.7096045197740113[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:   26.6s finished
#
# [2020-06-12 10:51:11] Features: 2/15 -- score: 0.7129378531073446[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:   24.4s finished
#
# [2020-06-12 10:51:35] Features: 3/15 -- score: 0.7129378531073446[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# ...

# %%
# Obtiene las características elegidas.
feat_cols = list(sfs1.k_feature_idx_)
print(feat_cols)

for idx in feat_cols:
    print(data.columns[idx])
# Out:
# [0, 1, 2, 5, 10, 12, 14, 15, 20, 21, 26, 28]
# school
# sex
# age
# Pstatus
# reason
# traveltime
# failures
# schoolsup
# higher
# internet
# Walc
# absences

# %%
data.dtypes
# Out:
# school           int8
# sex              int8
# age             int64
# address          int8
# famsize          int8
# Pstatus          int8
# Medu            int64
# Fedu            int64
# Mjob             int8
# Fjob             int8
# reason           int8
# guardian         int8
# traveltime      int64
# studytime       int64
# failures        int64
# schoolsup        int8
# famsup           int8
# paid             int8
# activities       int8
# nursery          int8
# higher           int8
# internet         int8
# romantic         int8
# famrel          int64
# freetime        int64
# goout           int64
# Dalc            int64
# Walc            int64
# health          int64
# absences        int64
# PROMEDIO      float64
# dtype: object
